# %% [markdown]
# # Sintesis Data dengan Library synthcity
# Lakukan sintesis data dengan library synthcity dengan plugin Bayesian Network, sintesis berjumlah 500 sampel

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the dataset "data_terbaru.csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the dataset "data_terbaru.csv" into a pandas DataFrame and display its first few rows and shape.

# %%
import pandas as pd

try:
    df = pd.read_csv('data_terbaru.csv')
    display(df.head())
    print(df.shape)
except FileNotFoundError:
    print("Error: 'data_terbaru.csv' not found.")
    df = None
except pd.errors.ParserError:
    print("Error: Could not parse 'data_terbaru.csv'. Check file format.")
    df = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df = None
# Out:
#    GRUP  BPMJ  BPMP  SPOJ  SPOP  SUHUJ  SUHUP
# 0     0    48    35    71    74  32.81  35.50
# 1     0    52    40    31    46  33.50  34.00
# 2     0    70    63    50    77  35.43  36.06
# 3     0    69    51    70    84  34.81  35.43
# 4     0    56    52    81    83  34.43  34.68
# (100, 7)

# %% [markdown]
# ## Data preparation
#
# ### Subtask:
# Prepare the loaded data for synthetic data generation using the synthcity library.

# %% [markdown]
# **Reasoning**:
# Handle missing values, encode categorical features, validate data types, and create a copy of the modified DataFrame.

# %%
# Check for missing values
print(df.isnull().sum())

# No missing values found in the provided head, so no imputation or removal is needed.

# Identify categorical features and apply one-hot encoding if necessary.
# Based on the provided head, 'GRUP' might be categorical.  Check unique values.
print(df['GRUP'].unique())

# If 'GRUP' has a limited number of unique values, it's categorical.  Let's assume it is.
# We'll use one-hot encoding.  If 'GRUP' contains more unique values, revise accordingly.

# One-hot encode 'GRUP'
df = pd.get_dummies(df, columns=['GRUP'], prefix=['GRUP'])

# Data Type Validation (ensure numerical columns are numeric)
for col in ['BPMJ', 'BPMP', 'SPOJ', 'SPOP', 'SUHUJ', 'SUHUP']:
    if not pd.api.types.is_numeric_dtype(df[col]):
        try:
            df[col] = pd.to_numeric(df[col], errors='coerce')
            print(f"Column '{col}' converted to numeric.")
        except Exception as e:
            print(f"Error converting '{col}' to numeric: {e}")


# Create a copy of the modified DataFrame
df_prepared = df.copy()

display(df_prepared.head())
# Out:
# GRUP     0
# BPMJ     0
# BPMP     0
# SPOJ     0
# SPOP     0
# SUHUJ    0
# SUHUP    0
# dtype: int64
# [0 1]
#    BPMJ  BPMP  SPOJ  SPOP  SUHUJ  SUHUP  GRUP_0  GRUP_1
# 0    48    35    71    74  32.81  35.50    True   False
# 1    52    40    31    46  33.50  34.00    True   False
# 2    70    63    50    77  35.43  36.06    True   False
# 3    69    51    70    84  34.81  35.43    True   False
# 4    56    52    81    83  34.43  34.68    True   False

# %% [markdown]
# ## Model training
#
# ### Subtask:
# Train a Bayesian Network model using the synthcity library on the prepared data.

# %%
import pandas as pd
df = pd.read_csv("/content/data_terbaru.csv")

# %%
df.describe()
# Out:
#              KODE        GRUP        BPMJ        BPMP        SPOJ        SPOP  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    39.420000    0.500000   64.900000   62.300000   81.800000   69.980000
# std     22.577892    0.502519   17.493722   20.132641   17.314092   18.704496
# min      0.000000    0.000000   27.000000   26.000000   31.000000   14.000000
# 25%     21.750000    0.000000   52.750000   48.750000   73.750000   57.500000
# 50%     40.500000    0.500000   64.000000   63.000000   85.000000   75.000000
# 75%     58.000000    1.000000   77.250000   75.000000   92.000000   83.250000
# max     79.000000    1.000000  113.000000  122.000000  174.000000  105.000000
#
#             SUHUJ       SUHUP
# count  100.000000  100.000000
# mean    35.356500   35.882100
# std      1.110196    0.870458
# min     32.810000   33.680000
# 25%     34.620000   35.365000
# 50%     35.400000   35.930000
# 75%     36.092500   36.422500
# max     37.750000   37.810000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   KODE    100 non-null    int64
#  1   GRUP    100 non-null    int64
#  2   BPMJ    100 non-null    int64
#  3   BPMP    100 non-null    int64
#  4   SPOJ    100 non-null    int64
#  5   SPOP    100 non-null    int64
#  6   SUHUJ   100 non-null    float64
#  7   SUHUP   100 non-null    float64
# dtypes: float64(2), int64(6)
# memory usage: 6.4 KB

# %%
df.columns
# Out:
# Index(['KODE', 'GRUP', 'BPMJ', 'BPMP', 'SPOJ', 'SPOP', 'SUHUJ', 'SUHUP'], dtype='object')

# %%
from synthcity.plugins import Plugins
Plugins(categories=["generic", "privacy"]).list()
# Out:
# [2025-04-08T11:52:04.802075+0000][2805][CRITICAL] module disabled: /usr/local/lib/python3.11/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# ['pategan',
#  'decaf',
#  'great',
#  'ddpm',
#  'dpgan',
#  'adsgan',
#  'privbayes',
#  'tvae',
#  'bayesian_network',
#  'aim',
#  'rtvae',
#  'arf',
#  'ctgan',
#  'nflow']

# %%
syn_model = Plugins().get("pategan")
syn_model.fit(df)
# Out:
# [2025-04-08T11:52:07.352933+0000][2805][CRITICAL] module disabled: /usr/local/lib/python3.11/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 10/10 [00:01<00:00,  8.25it/s]
# 100%|██████████| 10/10 [00:00<00:00, 10.23it/s]
# 100%|██████████| 10/10 [00:00<00:00, 11.37it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.52it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.33it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.81it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.48it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.49it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.33it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.59it/s]
# 100%|██████████| 10/10 [00:00<00:00, 11.72it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.61it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.96it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.26it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.56it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.79it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.58it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.63it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.53it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.63it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.40it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.89it/s]
# 100%|██████████| 10/10 [00:00<00:00, 10.72it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.43it/s]
# 100%|██████████| 10/10 [00:00<00:00, 10.86it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.56it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.76it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.68it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.30it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.56it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.55it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.57it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.57it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.56it/s]
# 100%|██████████| 10/10 [00:00<00:00, 10.07it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.74it/s]
# 100%|██████████| 10/10 [00:00<00:00, 11.38it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.23it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.26it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.65it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.39it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.53it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.32it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.59it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.15it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.36it/s]

# %%
print(synthetic_data)
# Out:
#      KODE  GRUP  BPMJ  BPMP  SPOJ  SPOP      SUHUJ      SUHUP
# 0      75     0    82    60    81    85  35.988910  34.549410
# 1      49     1    78    74    87    46  37.535706  36.346024
# 2      46     0    81    71    62    96  36.339062  37.810000
# 3      57     1    87    37    88    77  36.400514  34.983274
# 4      55     1    91    59    75    33  37.750000  36.239475
# 5      69     1    96    45    84    68  36.755619  36.108310
# 6      28     0    98    26    75    82  37.164153  36.316342
# 7      40     1    69    38    39    52  35.231697  37.266090
# 8      51     0    78    40    86    74  34.458482  35.394269
# 9      20     1    89    56    34    91  35.274144  37.744235
# 10     57     0    94    61   106    88  35.313563  34.339197
# 11     38     0    47    91   100    64  35.748320  34.924412
# 12     76     0    84    36    64    56  37.707186  34.429237
# 13     24     1    81    77    75    91  35.354305  37.789962
# 14     34     1    99    60    31    87  36.205929  36.879184
# 15     34     0    83    83    93    62  37.291369  34.308840
# 16     54     0    98    47    34    98  35.777380  37.810000
# 17     60     1   113    48    75    38  37.178007  35.022125
# 18     65     1    91    55    78    68  37.750000  35.793880
# 19     61     0   103    50    67    73  37.750000  37.810000
# 20     64     1   113    53    69    96  34.913245  37.787544
# 21     60     1    93    26    64    71  37.542338  37.810000
# 22     63     1   102    33    62    49  37.102625  37.015897
# 23     57     0   107    47    74    33  37.750000  36.767079
# 24     47     1   113    65    31    95  37.750000  35.442167
# 25     36     0   113    52    64    80  37.750000  36.282800
# 26     18     1    76    49    92    91  36.489612  35.344096
# 27     44     1    80    61    83    70  36.267634  35.822581
# 28     15     1    66    86    72    49  37.750000  35.434292
# 29     73     1    94    85   111    21  36.783164  34.002524
# 30     35     1   113    45    31   105  35.325704  37.810000
# 31     23     1   113    43    66   105  33.338282  37.078329
# 32     44     1   113    69    86    75  37.750000  34.090873
# 33      8     1   113    62    64    92  33.288331  37.775008
# 34     57     1   113    37    31   105  35.159262  36.438835
# 35     54     0   113    59    83    82  35.322853  36.496266
# 36     45     0   113    57    64    74  37.750000  37.402329
# 37     45     0    80    68    72    94  34.002947  36.945930
# 38     65     0    97    36    87    42  36.304898  36.456373
# 39     67     0    85    38    79    14  37.750000  34.352628
# 40     57     1   113    27    64   100  36.643257  36.277094
# 41     53     1   113    64    60    52  36.450530  37.810000
# 42     15     0    97    53    65    79  37.750000  36.220848
# 43     48     1   113    79    49    88  36.156690  37.810000
# 44     53     0    60    26    46    18  36.934638  36.952871
# 45     62     0   107    30    31    89  36.004032  36.725737
# 46     59     0   107    26    71    41  37.750000  36.834298
# 47     46     0   113    67    63    88  36.731925  37.803253
# 48     35     0   113    57    71    80  37.750000  37.254724
# 49     34     1   113    46    57   105  35.542210  36.950727
# 50     19     1    95    34    65   100  34.505937  37.810000
# 51     20     0    83    26    70    72  37.356516  37.644776
# 52     52     0    74    96    98    69  36.850574  33.680000
# 53     64     0   113    27    77    67  37.486878  36.121154
# 54     72     0   113    49    81    78  36.975175  35.480994
# 55     17     1    83    37    66    89  35.993479  35.836436
# 56     16     1    88    88    81    94  37.750000  36.729682
# 57     12     0    62    62    34    61  35.379003  37.810000
# 58     52     1    83    72    85    72  37.750000  35.378637
# 59     42     0   108    69    79   101  35.718086  36.200111
# 60     30     1    92   122    92    79  36.478429  36.054732
# 61     35     1    99    26    72    45  37.750000  35.147935
# 62     23     1    94    75    40    90  36.596948  37.125938
# 63     66     0    78    87   123    63  36.610536  33.680000
# 64     64     0    73    45    43    66  37.750000  34.435824
# 65     49     1   113    64    83    85  37.109633  33.728073
# 66     46     0    83    80    84    63  36.378610  35.445717
# 67     66     0   113    26    31    57  37.750000  36.835398
# 68     64     0    91    46    78    65  37.320175  36.168306
# 69     54     1   106    69    78    90  37.425986  37.204049
# 70     66     1    96    76    88    63  36.822882  34.498718
# 71     55     1   113    56    88    96  35.116186  35.667673
# 72     16     0    99    48    62    17  37.750000  37.555302
# 73     61     0    82    90    93    71  36.738706  34.234653
# 74     35     0   113    31    70    62  37.750000  37.040530
# 75     66     1   101    48    70    79  36.645985  36.536910
# 76     59     0    75    49    86    23  37.750000  35.351222
# 77     44     1    82    69    85    86  34.363836  36.459337
# 78     70     0   113    26    57    41  37.750000  36.624418
# 79     75     0    87    53   101    71  37.750000  35.372459
# 80     49     0    79    31    59    17  37.750000  37.810000
# 81     16     1    88    46    77    93  36.384112  36.980902
# 82     36     0    81    60    85    50  37.750000  34.810579
# 83     65     1    49    62    96    67  36.167640  35.461442
# 84     54     1   113    33    57    86  37.750000  37.810000
# 85     54     1   113    72    85   105  32.810000  35.579712
# 86     49     0    90    46    56    90  35.557214  36.972789
# 87     62     0    76    30    49   103  35.686548  37.810000
# 88     43     1    96   121    77    91  33.849939  34.182489
# 89     51     0    66   113   112    83  35.697246  36.004135
# 90     31     1   108    74    69    88  36.244957  37.810000
# 91     49     0   113    61    72    97  35.566112  36.797319
# 92     16     1    82    30    43    72  37.750000  36.817403
# 93     70     0   110    59    55    73  37.114939  33.774872
# 94     11     0   104    44    64   105  34.742517  37.810000
# 95     65     1    27    58    91    41  37.750000  35.021610
# 96     23     0   113    50    57    83  37.750000  37.810000
# 97     52     0    99    73    85    51  37.750000  36.528396
# 98     46     0    90   100    99   105  34.369056  34.547499
# 99     69     1   113    42    67    76  36.052842  36.554836
# 100    30     1    73   105    84    19  37.609345  35.730778
# 101    46     0    99    26    82    50  37.750000  35.545164
# 102    10     1   113    26    57    43  37.750000  37.664131
# 103     6     0    92    52    72    58  37.459197  35.711492
# 104     5     0    71    78    82    50  36.737844  37.152182
# 105    23     1    77    62    93   105  32.959091  34.815996
# 106    50     0    53    79    65   101  35.046354  37.810000
# 107    63     1   113    26    60    14  37.750000  37.633907
# 108    46     1    91    68    86    59  34.582924  35.576279
# 109    12     1    98    41    57    75  37.750000  37.810000
# 110    67     0    56    26    80    74  37.750000  37.308712
# 111     7     1   113    47    31    94  35.098319  37.389096
# 112    57     0    57    42    62    46  36.720552  35.422938
# 113    35     1    96    26    71    98  36.313034  37.810000
# 114    34     1   113    50    88    68  37.367875  35.263916
# 115    58     0   112    26    60    86  35.575105  37.363446
# 116    48     0   113    31    83    87  35.569623  35.815063
# 117    51     1    84    36    40    78  35.820798  36.206187
# 118    71     0   113    26    61    48  37.750000  35.567330
# 119    47     1   101    78    80    45  36.852814  35.699126
# 120    17     0    90    50    71    41  37.256524  37.752213
# 121    61     1    70    26    73    67  35.839770  37.595396
# 122    60     0   106    54    48    14  37.750000  36.323978
# 123    17     1   113    26    65    85  36.541369  37.572021
# 124    53     1   111    52    66    79  37.750000  36.529326
# 125    63     1    59    53   102    67  37.750000  36.737542
# 126    37     1    68   108   117    45  37.750000  33.680000
# 127    63     0    30    44    47    14  37.750000  37.579711
# 128    50     1    92    61    80    67  37.750000  35.739110
# 129    54     1   113    65    80    87  35.517864  36.968562
# 130    59     1   113    85    97    98  36.662487  35.211191
# 131    49     0   113    35    67    92  36.537743  36.458418
# 132    77     0    97    26    87    52  37.750000  34.062761
# 133    48     1   113    69    69   105  35.398683  36.589221
# 134    65     0   106    26    42    76  37.750000  37.038983
# 135    58     0   106    40    96    80  37.518543  34.375857
# 136    46     1   112    61    78    62  37.750000  37.810000
# 137    45     1   105    59    78    92  33.991089  35.677591
# 138    46     0    79    65    54    88  34.595528  34.785091
# 139    68     1    65    77   101    52  37.638708  34.436855
# 140    47     0   107    69    80    80  37.750000  36.254781
# 141    37     1   113    53    91    87  33.384030  34.575723
# 142    37     1    68    26    46    85  35.309409  37.810000
# 143    41     0   113    41    58    83  37.750000  37.810000
# 144    64     0    72    60    69    69  36.662462  36.487756
# 145    31     1   113    75    69    89  37.750000  37.800301
# 146    14     1   110    54    85    80  35.479540  36.107229
# 147    78     1    63    33    81    14  37.296170  37.183495
# 148    49     1   104    70    92    93  36.829393  34.472855
# 149     5     1   106    65    61    89  37.472140  35.919666
# 150    29     1    80    59    65    78  37.750000  36.516071
# 151    59     1   113    56    72    99  37.050040  36.550493
# 152    46     1   113    66    88    92  36.947672  35.614026
# 153    28     0   112    69    37    86  36.479282  37.214769
# 154    63     0    78    26    68    24  37.750000  36.020854
# 155    67     0    60    75    97    33  35.770402  35.212260
# 156    52     0    78    62    82    45  35.927847  36.164076
# 157    38     0   113    39    80    25  37.750000  34.828573
# 158    33     0   113    55    31    96  35.831062  37.279197
# 159    47     1    95    98    95    65  35.710790  35.292120
# 160    59     1   113    65    72    83  37.148835  37.810000
# 161    52     0    72    26    73    45  37.750000  35.686033
# 162    20     0    85    26    41    29  36.733433  35.868790
# 163    41     1   113    33    57    72  36.330973  37.335752
# 164    20     1    87   101    71    78  36.439960  36.151333
# 165    50     1    70    54    75    92  35.546442  36.731550
# 166    30     1    69    58    87    74  37.750000  35.876093
# 167    20     0    79    97    95    77  35.842127  34.494339
# 168    30     0    70    44    57    14  37.750000  36.610745
# 169    67     1    97    26    73    63  37.750000  36.736987
# 170    79     0   113    26    60    50  37.750000  34.874961
# 171    45     1    68    65    99    66  34.938006  35.624141
# 172    77     1    55    59   106    58  37.750000  35.237016
# 173    53     0   113    50    86    95  35.353953  37.027054
# 174    54     1    73    26    67    61  37.750000  37.374834
# 175    44     0   113    36    79    52  35.596747  35.625285
# 176    74     0    61    38    69    45  37.750000  36.918053
# 177    67     1    68    41    88    80  37.386696  35.647747
# 178    14     0   105    34    68    71  37.750000  37.103730
# 179    55     0    66    51    66    42  37.165859  37.616520
# 180    43     0    93    38    31    77  36.921452  37.810000
# 181    60     1   113    51    80    44  37.750000  35.181963
# 182    52     1   113    82    81    68  35.640134  35.789946
# 183    78     0   104    34    83    87  36.888132  36.069749
# 184    13     0    96    64    44    75  36.313862  36.721096
# 185    15     1   111    70    77    76  35.191299  37.808230
# 186    73     0    73    26    57    65  37.750000  37.810000
# 187    74     0    87    37    82    67  37.750000  36.284667
# 188     9     0    99    75    77    87  35.726267  37.810000
# 189    28     0   113    39    67    67  37.750000  37.810000
# 190    18     1    86    52    68    63  37.750000  37.703831
# 191    19     1   108    38    31    96  35.177172  37.280567
# 192    49     0    66    67    68    87  36.691771  36.947280
# 193    57     1   102    43    73    87  36.681785  35.823250
# 194    19     1   113    93    60   105  33.067510  36.782333
# 195    68     0   113    66    88    32  37.750000  33.952326
# 196     4     1    92    63    48   100  37.008695  37.112558
# 197    59     0   113    64    74    89  37.750000  37.457820
# 198    56     0    99    35    31   105  35.128757  36.715877
# 199    54     0    79    72    91    74  36.014811  34.041398
# 200    56     0   113    49    57    87  37.691988  37.171231
# 201    49     0   113    60    82    77  37.750000  35.882930
# 202    45     1   113    43    81    93  34.268920  34.923408
# 203    68     1   104    39    87    86  36.046879  35.443314
# 204    43     0    46    62    74    15  36.965087  35.952930
# 205    61     0   107    71    86    99  35.755949  36.450902
# 206    50     1   113    70    31    71  36.725585  37.810000
# 207    45     1    92    78    76    94  37.734700  37.731599
# 208    60     1   113    26    70    71  37.337253  35.689746
# 209    46     1   106    45    75   105  34.703394  37.678016
# 210    64     1    89    55    76    96  35.162662  36.865902
# 211    46     0   113    36    62    91  36.379714  36.945489
# 212    60     0   101    36    88    77  36.267673  34.759275
# 213    67     1    76    97    76    70  37.237762  36.907923
# 214    40     0    86    26    59    71  37.449282  37.434975
# 215    50     1   113    54    85    90  37.750000  34.717122
# 216     0     0   113    85    33    60  37.506906  37.205748
# 217     9     1   109    70    87    87  36.390677  35.803203
# 218    32     0   113    99    80    91  35.257126  35.989823
# 219    79     1    91    49    81    71  37.750000  35.470903
# 220    31     0   113    34    76    72  36.665646  36.856222
# 221    79     0    88    29    62    14  37.750000  37.810000
# 222    54     0    98    59    80    81  37.625999  36.166386
# 223    63     1    54    71    84    67  36.776498  36.635188
# 224    57     0    87    96    97    81  35.666501  35.079085
# 225    11     0   113    26    31    70  37.460641  37.304893
# 226    43     1   102    72    70    89  36.263993  36.800003
# 227    66     0    77    26    67    41  37.750000  36.441246
# 228    66     1    99    77    95    76  36.950266  35.015166
# 229    12     0   113    88    50   104  37.281397  36.445293
# 230    70     0    82    26    32    55  37.750000  36.593674
# 231    48     0   102    79    31    76  35.290526  37.810000
# 232    14     1    96    72    85    50  35.867158  35.992055
# 233    41     1   113    84    67   105  35.222477  37.810000
# 234    57     1    85    55    73    95  36.459142  36.938390
# 235    54     1    89    32    53    62  36.409591  37.256204
# 236    51     0   105    26    31    75  36.975415  37.583910
# 237    63     1    80    70    61    41  37.750000  35.604513
# 238    50     0   113    46    85    71  37.750000  35.637713
# 239    27     1   102    30    65    94  36.089406  36.073871
# 240    44     0    73    59    46    70  35.813994  34.926528
# 241    71     1    67    44    79    61  36.394656  35.284264
# 242    63     1    94    53    64    14  37.750000  36.392389
# 243    51     1    94    57    80    51  37.750000  36.328559
# 244    63     0    76    26    82    14  37.750000  35.208297
# 245    39     1   113    66    60    76  35.362150  37.810000
# 246    11     1    86    54    67    83  35.952702  36.045627
# 247    66     0   102    35    68    56  37.750000  37.244315
# 248     9     0   113    79    72    88  35.990013  37.810000
# 249    26     0    77    89    87    81  35.818118  35.980786
# 250    52     1   113    70    31   105  36.417962  37.810000
# 251    52     1   113    33    59    79  36.810064  37.030586
# 252    14     1   113    26    31    84  37.750000  37.783154
# 253    57     1   113    26    57    80  37.750000  37.810000
# 254    57     0   101    28    66    57  36.248653  36.182126
# 255    59     1    64    77    70    33  36.736358  34.879882
# 256    21     1   109    75    47   104  35.398230  35.725537
# 257    75     1    97    48    95    14  37.750000  33.680000
# 258    53     1   100    33    31    72  36.447089  37.568841
# 259    50     1   105    66    55    84  35.604684  35.879706
# 260    41     0   113    41    31    83  35.668669  35.792841
# 261    53     1    98    51    74    79  36.767298  36.645436
# 262    30     1   111    67    84    82  35.487679  34.325542
# 263    18     0   113    27    57    69  37.627773  37.810000
# 264    48     0    71    63    43   105  33.267700  37.810000
# 265    61     1   113    26    63    82  35.678485  37.441361
# 266    40     1   113    68    31    94  35.916567  37.102752
# 267    44     1    71    65    78    83  36.240674  36.159675
# 268    52     1    63    31    86    69  37.375478  36.269950
# 269    47     1    88    51    73    74  37.473911  36.539288
# 270    51     0    88    83    66    80  35.467807  34.367627
# 271    51     1    74    32    91    45  37.380147  35.944979
# 272    49     1   108    35    77    80  37.587881  34.822462
# 273    61     1    93    47    47    20  37.636564  35.633497
# 274    50     0    66    65    40    58  37.130911  37.454979
# 275    43     0    88    46    92    52  35.835822  35.313299
# 276    70     1   113    38    31    70  35.926226  35.380194
# 277    69     0    99    32    71    52  36.920928  34.538080
# 278    15     1   113    70    68   105  36.572905  36.727030
# 279    47     0   113    34    84    14  37.750000  33.898670
# 280    50     1    27    49    68    72  36.224590  37.810000
# 281    38     1    78    75    60    77  37.750000  35.199604
# 282    46     1   111    70    90    88  35.308653  34.055434
# 283    64     0    55    39    87    14  37.153615  35.458088
# 284    22     1   101    53    67    81  36.460775  37.361357
# 285    39     0   113    59    31    86  37.123700  36.661653
# 286    42     1    97    72    45    65  36.141366  37.653982
# 287    64     0   113    26    57    63  37.750000  37.223798
# 288    55     1    85    72    96    67  37.384319  33.680000
# 289    35     0   113    26    57    66  37.750000  37.567278
# 290    68     0    72    40    84    44  37.750000  36.244110
# 291    23     1   113    70    77    83  37.379237  36.915086
# 292    58     1    42   100    99    60  36.378939  34.788173
# 293    55     0    81    59    78    81  35.467569  35.198335
# 294    58     0    81    49    75    86  37.750000  36.423493
# 295    23     1    82    77    89    76  37.750000  34.573351
# 296    22     0   113    50    73    79  35.734620  36.707386
# 297    63     1   113    26    80    46  37.750000  35.781633
# 298    16     1    56    75   100    58  37.750000  34.730143
# 299    42     0   113    55    65    66  37.750000  37.810000
# 300    52     1    92    92    67   105  33.120833  37.450280
# 301    12     1    80    71    81    72  37.375577  36.120300
# 302    58     0   113    30    31    83  37.500208  37.588376
# 303    10     1   103    69    78    54  37.678939  34.599931
# 304    56     0    82    38    31    79  35.569151  37.567085
# 305    17     0    89    49    43    27  36.849894  35.915246
# 306    46     0   113    49    68    79  34.426412  37.001294
# 307    67     1    42    84    81    62  34.053370  35.818663
# 308    47     1    51    78   118    67  36.412686  34.228579
# 309    15     1    91    27    72    63  37.750000  36.501709
# 310    67     1    57    72    62    53  35.597031  37.541604
# 311    61     0    75    41    31    70  37.261861  37.810000
# 312    15     0    71    43    64    23  37.750000  37.176807
# 313    78     0   113    34    31    67  37.750000  37.744395
# 314    45     0   113    44    73    55  37.750000  35.597047
# 315    59     1   113    79    86    22  37.750000  35.376270
# 316    46     1   112    35    68    33  37.005981  35.597129
# 317    15     1    91    26    57    32  37.750000  37.810000
# 318    63     1   100    52    79    28  37.750000  36.088667
# 319    69     1    27    57    95    43  37.750000  34.762303
# 320    39     0   109    62    71    92  35.539210  37.810000
# 321    60     0   113    38    58    62  37.527049  37.680846
# 322    65     0    97    50    77    77  36.495478  36.585086
# 323    60     0   113    40    71    77  37.750000  37.530359
# 324    76     0    92    53    88    69  37.072521  33.691988
# 325    71     0    78    28    70    66  37.306611  35.907011
# 326    77     0    84    28    75    41  37.750000  34.693292
# 327    56     1   113    65    86    62  37.536114  35.995239
# 328    55     1   113    77    80    93  36.148121  37.099212
# 329    62     1    47    48    81    64  37.750000  36.290394
# 330    50     0   108    59    75    74  37.202050  37.522923
# 331    62     0    96    26    76    48  37.750000  36.288629
# 332    46     1   107    65    58    43  37.476210  36.734922
# 333    60     1    80    95    99    68  35.387515  35.103855
# 334    59     0    81    66    52   102  35.285561  35.510550
# 335    52     1   110    26    67    21  37.750000  37.041525
# 336    63     0    56    26    85    70  36.980780  37.417978
# 337    17     1   113    46    59    75  36.445714  37.810000
# 338    79     1    83    69    90    63  36.686620  36.368139
# 339    66     0    79    40    49    62  37.750000  36.676591
# 340    75     0    61    61    46    84  36.171138  37.810000
# 341    16     0    85    57    78    87  35.435949  36.196540
# 342    47     0   113    79    66   101  34.310187  35.542961
# 343    61     1   113    26    69    79  36.623179  37.808913
# 344    46     0   109    41    31    82  36.617152  36.317771
# 345    55     0   101    27    51    39  36.082088  37.364571
# 346    55     0   113    29    61    98  36.254355  37.810000
# 347    46     1   102    39    81    79  37.263085  36.382195
# 348    65     1    67    26    31    76  36.613635  37.810000
# 349     0     1   102    82    89   105  33.840358  35.471825
# 350    61     1    44    66   102    55  37.750000  33.680000
# 351    63     1    94    35    31    67  37.750000  37.157138
# 352    58     0   113    56    31   103  35.129657  37.410616
# 353     7     0   113    47    80    93  34.713136  37.006892
# 354    54     0    87    84    42    88  36.753924  36.180323
# 355    35     0   106    66    31   103  35.710286  37.810000
# 356    69     1    85    72    68    76  37.472366  37.011025
# 357    55     1    58    59    31    83  35.944896  37.428382
# 358    54     0   102    68    40    42  36.650049  37.810000
# 359    60     0    61    38    79    15  37.686399  35.725610
# 360    51     0    97    83    83    75  36.271542  35.218749
# 361    54     0   104    75    60    85  35.384785  36.291866
# 362    57     0    85    91    72    73  35.702049  35.801856
# 363    49     1   113    49    71    66  37.165521  37.026843
# 364    38     0    62    73    85    79  35.740425  35.958949
# 365    49     1    84    58    69    74  36.393792  36.851865
# 366    58     0    84    40    48    15  37.609158  34.901583
# 367    29     0    66    89    95    50  37.496746  35.032340
# 368    57     0   103    32    45    84  34.136330  35.813013
# 369    52     1   113    45    61    86  35.616810  36.947927
# 370    58     1    60    58    92    67  37.260136  35.858699
# 371    60     1    61    50    36    75  35.536425  36.844273
# 372    45     0   113    65    41    91  37.251469  34.830818
# 373    46     1    84   108    82    56  37.750000  36.416465
# 374    51     0   113    47    75    90  35.837615  36.503191
# 375    44     0   113    26    57    87  36.750482  37.741698
# 376    21     0   113    51    84    69  37.750000  33.680000
# 377    29     1    72    78    85    95  34.522487  36.791722
# 378    55     0   103    26    80    81  36.144637  37.547119
# 379    20     0   111    42    70    60  37.515042  35.183061
# 380    51     0   106    73    68    70  37.055682  35.105507
# 381    79     0    66    35    71    41  37.750000  34.880375
# 382    31     0    94    40    57    84  36.821581  37.810000
# 383    79     0    27    57   102    14  37.750000  34.764362
# 384    65     0    57    41    81    43  36.741405  36.544183
# 385    46     0    87    48    68    51  36.450754  37.293684
# 386    21     0    87    62    36    88  35.119521  37.742417
# 387    66     1    33    61    33    14  37.750000  37.810000
# 388    52     0   111    74    88    72  37.151196  33.941205
# 389    59     0   113    72    37    92  34.617859  36.692762
# 390    44     1   113    36    72    76  37.750000  36.544691
# 391    63     0    75    70    97    47  35.986683  35.988439
# 392    59     1    81    26    66    59  37.750000  37.810000
# 393    54     0    89    69    85    78  36.504378  35.523854
# 394    16     1    79    64    65    72  37.595659  36.047155
# 395    13     1    74    67    75    69  35.195571  37.673043
# 396    16     0   113    44    78    72  36.398912  35.115524
# 397    54     1    96    95    86   102  36.384203  36.055411
# 398    49     0   113    51    71    80  37.263266  34.762802
# 399    71     0    84    55    78    62  37.750000  36.288199
# 400    61     1    62    55    96    79  34.463054  33.934234
# 401    17     0   113    35    57    82  37.750000  37.198641
# 402    52     1    82    85   173    87  35.916952  36.582296
# 403    41     0   103    41    79    95  35.766354  35.382927
# 404    64     0    61    36    96    50  37.000198  34.563224
# 405    46     0   113    37    71    95  36.125339  36.820763
# 406    45     1    77    47    74    75  37.054557  35.900528
# 407    50     1   113    71    94    62  37.076784  35.746154
# 408    57     0   106    26    31    82  35.111172  37.236774
# 409     6     0    84    57    67    52  37.750000  37.252630
# 410    52     0    94    37    72    91  36.868348  36.132185
# 411    54     1   100    48    85    64  37.750000  35.242262
# 412    16     1   113    26    79    88  35.507649  36.313378
# 413    21     1    82   105    74    96  34.511619  35.456797
# 414    79     0   107    32    77    50  36.844726  35.225070
# 415    54     1   113    28    69    19  37.750000  35.222645
# 416    38     1    70    86    85    74  35.413944  36.602905
# 417    53     0    91    26    68    66  37.750000  35.565868
# 418    67     0   113    26    58    83  36.664317  36.799861
# 419    29     0    98    54   101    75  37.395496  35.238876
# 420    46     1   113    46    77    73  37.750000  35.725031
# 421    61     0    88    65   110    84  36.878428  33.680000
# 422    26     0   113    26    31    55  37.750000  37.810000
# 423    51     1    92    63    31    92  36.778684  37.810000
# 424    49     1    62    64    90    62  36.513527  35.069552
# 425    79     0    84    43    83    52  36.897782  36.915605
# 426    60     0   113    51    72    98  35.359010  37.162959
# 427    41     1   113    37    89    86  37.324344  35.925979
# 428    54     1   112    40    57    70  37.750000  37.810000
# 429    59     0    96    46    74    95  34.164845  37.649886
# 430    45     0   113    58    75    59  37.750000  34.945190
# 431    79     0    88    26    79    49  37.750000  35.636699
# 432    62     0    69    42    85    50  37.588304  35.216174
# 433    67     1    85    45    80    77  36.770930  35.466826
# 434    22     1   113    49    78    99  35.550729  36.295881
# 435    50     1    86    59    79    83  35.441493  36.800673
# 436    21     0    94    49    81    53  37.073413  34.836613
# 437    60     1    31    69    67    56  34.677728  37.580579
# 438    59     1   113    31    71    75  37.750000  36.767710
# 439    63     0    87    37    57    86  35.721061  37.810000
# 440    58     1   108    91    75   105  32.810000  37.177230
# 441    49     1    97    70    93    88  35.561882  35.470936
# 442    53     1    50    62    77    41  36.906510  36.392302
# 443    34     0   112    47    31    80  35.673197  36.734667
# 444    20     0    68    60   108    43  35.556885  34.870280
# 445    59     1   106    49    89    85  36.917901  35.803379
# 446    69     1    86    29    31    70  37.658897  37.460496
# 447    41     0   105    60    48    55  37.750000  34.574057
# 448    41     0   105    42    31   105  37.135157  37.810000
# 449    52     1   113    34    57    83  37.750000  37.810000
# 450    61     1    86    38    86    70  37.337114  34.892419
# 451    71     1   100    49    81    71  36.587123  35.053571
# 452    47     0   111    48    72    68  37.450669  36.580109
# 453    49     1    96    79    87    46  37.750000  34.944603
# 454    52     1    83    43    81    88  34.377280  36.069951
# 455    59     0    73    91    91    67  35.699177  34.973156
# 456    75     0    65    37   103    41  37.750000  33.808304
# 457    53     1    80    73    90    87  37.750000  35.412497
# 458    18     1   113   112    51    54  36.431946  36.193833
# 459    50     1    44    79    56    84  35.081558  36.235893
# 460    59     0    96    61    73    70  37.750000  37.447179
# 461    42     1   111    65    33    62  37.750000  37.810000
# 462    17     0   100    79    88    62  35.982685  35.685755
# 463    55     0   103   104   118    69  35.274126  33.680000
# 464    54     0    84    73    94    77  35.779458  36.674482
# 465    61     1    86   100    72    84  35.086280  35.961262
# 466    48     0    82    43    31    57  37.750000  37.067631
# 467    23     1   102    32    31    90  36.251699  37.810000
# 468    56     0    72    65    45    74  37.154083  37.129065
# 469    66     0    58    55    56    69  36.794234  34.558647
# 470    52     1    93    64    38    60  36.658845  37.779293
# 471    73     0    86    60    53    57  37.750000  37.657710
# 472    54     1   111    70    77    91  36.836643  37.150813
# 473    69     1   100    74    68    87  35.470704  37.600326
# 474    59     1    69    26    70    75  36.501229  37.810000
# 475    50     0   113    31    59    94  36.566674  37.392366
# 476    48     1    81    47    35    76  37.222720  37.438093
# 477    57     1    96    65    31    88  37.393068  37.810000
# 478    62     0   113    60    74    61  36.468004  34.393488
# 479    49     0    99    42    86    88  35.462693  34.428658
# 480    64     0    83    27    74    61  37.750000  37.810000
# 481    64     0   105    41    74    92  36.327897  36.351077
# 482    17     1    96    56    63    78  35.693129  36.798161
# 483    48     1   113    66    69    81  37.750000  37.034802
# 484    54     1    46    88    91    90  35.804913  36.812564
# 485    51     1   100    48    81    65  37.443650  36.836824
# 486    58     0   113    61    68    91  36.740662  36.608978
# 487    66     0    81    30    31    62  37.750000  37.810000
# 488    59     0    70    82   102    63  35.989905  34.543441
# 489    12     1    78    45    75    75  36.697747  36.508442
# 490    66     1    65    84    91    70  37.160506  37.007171
# 491    40     0    93    78    81    93  35.967607  36.475141
# 492    79     0    97    27    86    45  37.750000  33.777112
# 493     0     0   113    91    60   105  36.288435  37.810000
# 494    42     0    62    75    79    34  37.750000  35.726796
# 495    50     0   113    80    92    99  33.708782  35.128914
# 496    61     1    87    63    75    56  36.363863  35.899084
# 497    36     0    83    68    38   103  34.094257  37.119447
# 498    61     0   113    31    57    91  36.911191  37.810000
# 499    61     0    60    51    90    21  37.104266  33.720921

# %% [markdown]
# ## Model  Evaluation

# %% [markdown]
# ### KS Test

# %%
# Periksa statistik deskriptif dari data asli
print("Statistik Data Asli:")
print(df.describe())

# Periksa statistik deskriptif dari data sintetis
print("\nStatistik Data Sintetis:")
synthetic_df = synthetic_data.dataframe()
print(synthetic_df.describe())
# Out:
# Statistik Data Asli:
#              KODE        GRUP        BPMJ        BPMP        SPOJ        SPOP  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    39.420000    0.500000   64.900000   62.300000   81.800000   69.980000
# std     22.577892    0.502519   17.493722   20.132641   17.314092   18.704496
# min      0.000000    0.000000   27.000000   26.000000   31.000000   14.000000
# 25%     21.750000    0.000000   52.750000   48.750000   73.750000   57.500000
# 50%     40.500000    0.500000   64.000000   63.000000   85.000000   75.000000
# 75%     58.000000    1.000000   77.250000   75.000000   92.000000   83.250000
# max     79.000000    1.000000  113.000000  122.000000  174.000000  105.000000
#
#             SUHUJ       SUHUP
# count  100.000000  100.000000
# mean    35.356500   35.882100
# std      1.110196    0.870458
# min     32.810000   33.680000
# 25%     34.620000   35.365000
# 50%     35.400000   35.930000
# 75%     36.092500   36.422500
# max     37.750000   37.810000
#
# Statistik Data Sintetis:
#              KODE        GRUP        BPMJ        BPMP        SPOJ        SPOP  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    47.642000    0.494000   92.792000   54.464000   69.936000   70.632000
# std     18.277362    0.500465   19.855811   20.655508   20.123464   22.248924
# min      0.000000    0.000000   27.000000   26.000000   31.000000   14.000000
# 25%     38.000000    0.000000   81.000000   37.000000   58.750000   58.750000
# 50%     51.000000    0.000000   97.000000   53.000000   72.000000   74.000000
# 75%     61.000000    1.000000  113.000000   69.000000   84.000000   87.000000
# max     79.000000    1.000000  113.000000  122.000000  173.000000  105.000000
#
#             SUHUJ       SUHUP
# count  500.000000  500.000000
# mean    36.624949   36.304398
# std      1.122244    1.161284
# min     32.810000   33.680000
# 25%     35.817087   35.460603
# 50%     36.826137   36.440040
# 75%     37.750000   37.305848
# max     37.750000   37.810000

# %%
df_asli = pd.DataFrame(df)
df_sintesis = pd.DataFrame(synthetic_df)

# %%
import pandas as pd
from scipy.stats import ks_2samp

# Membuat DataFrame
df_asli = pd.DataFrame(df)
df_sintesis = pd.DataFrame(synthetic_df)

# Melakukan uji Kolmogorov-Smirnov untuk setiap kolom
ks_results = {col: ks_2samp(df_asli[col], df_sintesis[col]) for col in df.keys()}

ks_results
# Out:
# {'KODE': KstestResult(statistic=0.23, pvalue=0.0002503716555522677, statistic_location=40, statistic_sign=1),
#  'GRUP': KstestResult(statistic=0.006, pvalue=1.0, statistic_location=0, statistic_sign=-1),
#  'BPMJ': KstestResult(statistic=0.566, pvalue=2.467571813725868e-25, statistic_location=79, statistic_sign=1),
#  'BPMP': KstestResult(statistic=0.192, pvalue=0.0038369748542590085, statistic_location=49, statistic_sign=-1),
#  'SPOJ': KstestResult(statistic=0.346, pvalue=2.4162452987440573e-09, statistic_location=79, statistic_sign=-1),
#  'SPOP': KstestResult(statistic=0.108, pvalue=0.2724966677507765, statistic_location=86, statistic_sign=1),
#  'SUHUJ': KstestResult(statistic=0.482, pvalue=3.98756214722495e-18, statistic_location=36.25, statistic_sign=1),
#  'SUHUP': KstestResult(statistic=0.268, pvalue=9.79835834861779e-06, statistic_location=36.81, statistic_sign=1)}

# %%
from synthcity.utils.serialization import load, load_from_file, save, save_to_file
buff = save(syn_model)
type(buff)
# Out:
# bytes

# %%
reloaded = load(buff)
reloaded.name()
# Out:
# 'pategan'

# %%
df_sintesis.to_csv('sampel500_pategan.csv', index=True)

# %%
from synthcity.plugins.core.dataloader import DataLoader

from synthcity.plugins.core.models.tabular_gan import TabularGAN

from synthcity.plugins.core.dataloader import GenericDataLoader

# %%
generic_loader = GenericDataLoader(df)

# %%
torch_dataloader = load(buff)

# %%
from synthcity.plugins.core.dataloader import GenericDataLoader
from synthcity.benchmark import Benchmarks
import pprint

# Bungkus data asli dan sintetis
real_loader = GenericDataLoader(df, target_column=None)
synthetic_loader = GenericDataLoader(synthetic_df, target_column=None)

# Tes dan metrik
tests = [("custom_generator", "synthetic", synthetic_loader)]  # custom_generator = nama plugin bebas
metrics = {
    "statistical": {},
    "privacy": {}
}

from synthcity.benchmark import Benchmarks

results = Benchmarks.evaluate(
    tests=[("marginal_distributions", "marginal_distributions", {})],
    X=real_loader,  # ini data asli
    synthetic=synthetic_loader,
    synthetic_size=500,
    repeats=1
)


# Tampilkan hasil
pprint.pprint(results)
# Out:
# {'marginal_distributions':                                                         min       max  \
# sanity.data_mismatch.score                         0.000000  0.000000
# sanity.common_rows_proportion.score                0.000000  0.000000
# sanity.nearest_syn_neighbor_distance.mean          0.417713  0.417713
# sanity.close_values_probability.score              0.150000  0.150000
# sanity.distant_values_probability.score            0.050000  0.050000
# stats.jensenshannon_dist.marginal                  0.039248  0.039248
# stats.chi_squared_test.marginal                    0.094144  0.094144
# stats.inv_kl_divergence.marginal                   0.292115  0.292115
# stats.ks_test.marginal                             0.637500  0.637500
# stats.max_mean_discrepancy.joint                   0.100000  0.100000
# stats.wasserstein_dist.joint                       0.667204  0.667204
# stats.prdc.precision                               0.650000  0.650000
# stats.prdc.recall                                  1.000000  1.000000
# stats.prdc.density                                 0.300000  0.300000
# stats.prdc.coverage                                0.650000  0.650000
# stats.alpha_precision.delta_precision_alpha_OC     0.003333  0.003333
# stats.alpha_precision.delta_coverage_beta_OC       0.091264  0.091264
# stats.alpha_precision.authenticity_OC              1.000000  1.000000
# stats.alpha_precision.delta_precision_alpha_naive  0.156667  0.156667
# stats.alpha_precision.delta_coverage_beta_naive    0.173793  0.173793
# stats.alpha_precision.authenticity_naive           0.800000  0.800000
# detection.detection_xgb.mean                       0.845805  0.845805
# detection.detection_mlp.mean                       0.559524  0.559524
# detection.detection_gmm.mean                       0.519841  0.519841
# detection.detection_linear.mean                    0.693878  0.693878
# privacy.delta-presence.score                       2.333333  2.333333
# privacy.k-anonymization.gt                         6.000000  6.000000
# privacy.k-anonymization.syn                        6.000000  6.000000
# privacy.k-map.score                                6.000000  6.000000
# privacy.distinct l-diversity.gt                    6.000000  6.000000
# privacy.distinct l-diversity.syn                   6.000000  6.000000
# privacy.identifiability_score.score                0.100000  0.100000
# privacy.identifiability_score.score_OC             0.050000  0.050000
# privacy.DomiasMIA_BNAF.accuracy                    0.422222  0.422222
# privacy.DomiasMIA_BNAF.aucroc                      0.476875  0.476875
#
#                                                        mean  stddev    median  \
# sanity.data_mismatch.score                         0.000000     0.0  0.000000
# sanity.common_rows_proportion.score                0.000000     0.0  0.000000
# sanity.nearest_syn_neighbor_distance.mean          0.417713     0.0  0.417713
# sanity.close_values_probability.score              0.150000     0.0  0.150000
# sanity.distant_values_probability.score            0.050000     0.0  0.050000
# stats.jensenshannon_dist.marginal                  0.039248     0.0  0.039248
# stats.chi_squared_test.marginal                    0.094144     0.0  0.094144
# stats.inv_kl_divergence.marginal                   0.292115     0.0  0.292115
# stats.ks_test.marginal                             0.637500     0.0  0.637500
# stats.max_mean_discrepancy.joint                   0.100000     0.0  0.100000
# stats.wasserstein_dist.joint                       0.667204     0.0  0.667204
# stats.prdc.precision                               0.650000     0.0  0.650000
# stats.prdc.recall                                  1.000000     0.0  1.000000
# stats.prdc.density                                 0.300000     0.0  0.300000
# stats.prdc.coverage                                0.650000     0.0  0.650000
# stats.alpha_precision.delta_precision_alpha_OC     0.003333     0.0  0.003333
# stats.alpha_precision.delta_coverage_beta_OC       0.091264     0.0  0.091264
# stats.alpha_precision.authenticity_OC              1.000000     0.0  1.000000
# stats.alpha_precision.delta_precision_alpha_naive  0.156667     0.0  0.156667
# stats.alpha_precision.delta_coverage_beta_naive    0.173793     0.0  0.173793
# stats.alpha_precision.authenticity_naive           0.800000     0.0  0.800000
# detection.detection_xgb.mean                       0.845805     0.0  0.845805
# detection.detection_mlp.mean                       0.559524     0.0  0.559524
# detection.detection_gmm.mean                       0.519841     0.0  0.519841
# detection.detection_linear.mean                    0.693878     0.0  0.693878
# privacy.delta-presence.score                       2.333333     0.0  2.333333
# privacy.k-anonymization.gt                         6.000000     0.0  6.000000
# privacy.k-anonymization.syn                        6.000000     0.0  6.000000
# privacy.k-map.score                                6.000000     0.0  6.000000
# privacy.distinct l-diversity.gt                    6.000000     0.0  6.000000
# privacy.distinct l-diversity.syn                   6.000000     0.0  6.000000
# privacy.identifiability_score.score                0.100000     0.0  0.100000
# privacy.identifiability_score.score_OC             0.050000     0.0  0.050000
# privacy.DomiasMIA_BNAF.accuracy                    0.422222     0.0  0.422222
# privacy.DomiasMIA_BNAF.aucroc                      0.476875     0.0  0.476875
#
#                                                    iqr rounds errors  \
# sanity.data_mismatch.score                         0.0      1      0
# sanity.common_rows_proportion.score                0.0      1      0
# sanity.nearest_syn_neighbor_distance.mean          0.0      1      0
# sanity.close_values_probability.score              0.0      1      0
# sanity.distant_values_probability.score            0.0      1      0
# stats.jensenshannon_dist.marginal                  0.0      1      0
# stats.chi_squared_test.marginal                    0.0      1      0
# stats.inv_kl_divergence.marginal                   0.0      1      0
# stats.ks_test.marginal                             0.0      1      0
# stats.max_mean_discrepancy.joint                   0.0      1      0
# stats.wasserstein_dist.joint                       0.0      1      0
# stats.prdc.precision                               0.0      1      0
# stats.prdc.recall                                  0.0      1      0
# stats.prdc.density                                 0.0      1      0
# stats.prdc.coverage                                0.0      1      0
# stats.alpha_precision.delta_precision_alpha_OC     0.0      1      0
# stats.alpha_precision.delta_coverage_beta_OC       0.0      1      0
# stats.alpha_precision.authenticity_OC              0.0      1      0
# stats.alpha_precision.delta_precision_alpha_naive  0.0      1      0
# stats.alpha_precision.delta_coverage_beta_naive    0.0      1      0
# stats.alpha_precision.authenticity_naive           0.0      1      0
# detection.detection_xgb.mean                       0.0      1      0
# detection.detection_mlp.mean                       0.0      1      0
# detection.detection_gmm.mean                       0.0      1      0
# detection.detection_linear.mean                    0.0      1      0
# privacy.delta-presence.score                       0.0      1      0
# privacy.k-anonymization.gt                         0.0      1      0
# privacy.k-anonymization.syn                        0.0      1      0
# privacy.k-map.score                                0.0      1      0
# privacy.distinct l-diversity.gt                    0.0      1      0
# privacy.distinct l-diversity.syn                   0.0      1      0
# privacy.identifiability_score.score                0.0      1      0
# privacy.identifiability_score.score_OC             0.0      1      0
# privacy.DomiasMIA_BNAF.accuracy                    0.0      1      0
# privacy.DomiasMIA_BNAF.aucroc                      0.0      1      0
#
#                                                    durations direction
# sanity.data_mismatch.score                              0.00  minimize
# sanity.common_rows_proportion.score                     0.01  minimize
# sanity.nearest_syn_neighbor_distance.mean               0.01  minimize
# sanity.close_values_probability.score                   0.00  maximize
# sanity.distant_values_probability.score                 0.00  minimize
# stats.jensenshannon_dist.marginal                       0.02  minimize
# stats.chi_squared_test.marginal                         0.00  maximize
# stats.inv_kl_divergence.marginal                        0.01  maximize
# stats.ks_test.marginal                                  0.01  maximize
# stats.max_mean_discrepancy.joint                        0.01  minimize
# stats.wasserstein_dist.joint                            0.02  minimize
# stats.prdc.precision                                    0.02  maximize
# stats.prdc.recall                                       0.02  maximize
# stats.prdc.density                                      0.02  maximize
# stats.prdc.coverage                                     0.02  maximize
# stats.alpha_precision.delta_precision_alpha_OC          0.03  maximize
# stats.alpha_precision.delta_coverage_beta_OC            0.03  maximize
# stats.alpha_precision.authenticity_OC                   0.03  maximize
# stats.alpha_precision.delta_precision_alpha_naive       0.03  maximize
# stats.alpha_precision.delta_coverage_beta_naive         0.03  maximize
# stats.alpha_precision.authenticity_naive                0.03  maximize
# detection.detection_xgb.mean                            0.02  minimize
# detection.detection_mlp.mean                            0.03  minimize
# detection.detection_gmm.mean                            0.02  minimize
# detection.detection_linear.mean                         0.03  minimize
# privacy.delta-presence.score                            0.02  maximize
# privacy.k-anonymization.gt                              0.02  maximize
# privacy.k-anonymization.syn                             0.02  maximize
# privacy.k-map.score                                     0.01  maximize
# privacy.distinct l-diversity.gt                         0.04  maximize
# privacy.distinct l-diversity.syn                        0.04  maximize
# privacy.identifiability_score.score                     0.05  minimize
# privacy.identifiability_score.score_OC                  0.05  minimize
# privacy.DomiasMIA_BNAF.accuracy                         0.02  minimize
# privacy.DomiasMIA_BNAF.aucroc                           0.02  minimize  }

# %% [markdown]
# ### Corelattion Matrix
#
# Mengukur hubungan linier antar variabel numerik. Kita bandingkan korelasi antar kolom di data asli vs sintetis. Jika beda jauh → struktur hubungan rusak.
#
# * Di dalam data sintetis itu sendiri (apakah masuk akal dan konsisten), dan
#
# * Antara data sintetis dan data asli (apakah pola-pola hubungan antarkolom tetap terjaga).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
df_real = pd.read_csv("data_terbaru.csv")
df_synth = pd.read_csv("/content/sampel500_pategan.csv")

# Hitung korelasi
corr_real = df_real.corr(numeric_only=True)
corr_synth = df_synth.corr(numeric_only=True)

# %%
# Plot perbandingan korelasi
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sns.heatmap(corr_real, ax=axs[0], annot=True, cmap="Blues", cbar=False)
axs[0].set_title("Korelasi Data Asli")

sns.heatmap(corr_synth, ax=axs[1], annot=True, cmap="Greens", cbar=False)
axs[1].set_title("Korelasi Data Sintetis (pate gan)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### PCA (Principal Component Analysis)
#
# Mengurangi dimensi & memvisualisasikan data. Jika pola distribusi komponen utama berbeda antara asli dan sintetis → struktur data berbeda.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Reload data
df_real = pd.read_csv("data_terbaru.csv")
df_synth = pd.read_csv("/content/sampel500_pategan.csv")

# %%
# Ambil hanya kolom numerik dan drop NaN jika ada
df_real_num = df_real.select_dtypes(include=['float64', 'int64']).dropna()
df_synth_num = df_synth.select_dtypes(include=['float64', 'int64']).dropna()

# Standarisasi data sebelum PCA
scaler = StandardScaler()
real_scaled = scaler.fit_transform(df_real_num)
synth_scaled = scaler.transform(df_synth_num)

# %%
# PCA - Ambil 2 komponen utama
pca = PCA(n_components=2)
real_pca = pca.fit_transform(real_scaled)
synth_pca = pca.transform(synth_scaled)

# %%
# Plotting hasil PCA
plt.figure(figsize=(10, 6))
plt.scatter(real_pca[:, 0], real_pca[:, 1], alpha=0.6, label='Data Asli', color='blue')
plt.scatter(synth_pca[:, 0], synth_pca[:, 1], alpha=0.6, label='Data Sintetis (pate gan)', color='green')
plt.xlabel('Komponen Utama 1')
plt.ylabel('Komponen Utama 2')
plt.title('Visualisasi PCA (2D) Data Asli vs Sintetis')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### TSTR (Train on Synthetic, Test on Real)
#
# Hasil data augmentasi dijadikan data training sedangkan data asli jadi data testing.
#
# 🧠 Tujuan Uji Ini: Kita ingin tahu apakah data sintetik (hasil augmentasi) cukup berkualitas untuk melatih model yang tetap akurat saat diuji di data asli.
#
# Dengan begitu, kamu bisa percaya bahwa data hasil augmentasi ini benar-benar punya "nilai fungsional".

# %% [markdown]
# #### RF

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
df_real = pd.read_csv("/content/data_terbaru.csv")
df_pategan = pd.read_csv("/content/sampel500_pategan.csv")

# %%
df_real.shape[0]  # Menampilkan jumlah baris
# Out:
# 100

# %%
df_pategan.shape[0]
# Out:
# 500

# %%
def get_X_y(df):
    X = df.drop(columns=["GRUP"])
    y = df["GRUP"]
    return X, y

X_real, y_real = get_X_y(df_real)
X_pategan, y_pategan = get_X_y(df_pategan)

# %%
# 🤖 Model: Train di Bayesian, Test di Data Asli
# ======================
model_pategan = RandomForestClassifier(random_state=42)
model_pategan.fit(X_pategan, y_pategan)

# Drop 'Unnamed: 0' before fitting
X_pategan = X_pategan.drop(columns=['Unnamed: 0'], errors='ignore')
# errors='ignore' prevents error if the column doesn't exist

model_pategan.fit(X_pategan, y_pategan)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_pategan = model_pategan.predict(X_real)
print("📊 Performance (Train on pategan → Test on REAL):")
print(classification_report(y_real, y_pred_pategan))
# Out:
# 📊 Performance (Train on pategan → Test on REAL):
#               precision    recall  f1-score   support
#
#            0       0.57      0.26      0.36        50
#            1       0.52      0.80      0.63        50
#
#     accuracy                           0.53       100
#    macro avg       0.54      0.53      0.49       100
# weighted avg       0.54      0.53      0.49       100

# %% [markdown]
# ##### HYPERPARAMETER TUNING

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Inisialisasi model dasar
model_rf = RandomForestClassifier(random_state=42)

# Ruang hyperparameter
grid_space = {
    'max_depth': [3, 5, 10, None],
    'n_estimators': [10, 100, 200],
    'max_features': [1, 3, 5, 7],
    'min_samples_leaf': [1, 2, 3],
    'min_samples_split': [2, 3]  # ← fix: tidak boleh 1
}

# %%
# Grid Search dengan cross-validation 3-fold
grid = GridSearchCV(
    model_rf,
    param_grid=grid_space,
    cv=3,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)
# Lakukan tuning: train di data sintetik pategan
grid.fit(X_pategan, y_pategan)
# Out:
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 10, None],
#                          'max_features': [1, 3, 5, 7],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3],
#                          'n_estimators': [10, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
# Gunakan model terbaik untuk prediksi di data asli
best_model = grid.best_estimator_
y_pred = best_model.predict(X_real)

# %%
# Tampilkan hasil evaluasi
print("📈 Best Params:", grid.best_params_)
print("\n📊 Evaluation (After Tuning):")
print(classification_report(y_real, y_pred))
# Out:
# 📈 Best Params: {'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100}
#
# 📊 Evaluation (After Tuning):
#               precision    recall  f1-score   support
#
#            0       0.50      0.16      0.24        50
#            1       0.50      0.84      0.63        50
#
#     accuracy                           0.50       100
#    macro avg       0.50      0.50      0.43       100
# weighted avg       0.50      0.50      0.43       100

# %% [markdown]
# #### LR

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# Fungsi bantu tetap sama
def get_X_y(df):
    X = df.drop(columns=["GRUP"])
    y = df["GRUP"]
    return X, y

# %%
# Ambil data training & testing
X_real, y_real = get_X_y(df_real)
X_pategan, y_pategan = get_X_y(df_pategan)

# Bersihkan kolom jika ada 'Unnamed: 0'
X_pategan = X_pategan.drop(columns=['Unnamed: 0'], errors='ignore')
X_real = X_real.drop(columns=['Unnamed: 0'], errors='ignore')

# %%
# Inisialisasi model Logistic Regression
model_logreg = LogisticRegression(max_iter=1000, solver='liblinear')  # solver untuk dataset kecil

# Train model di data sintetik (Bayesian)
model_logreg.fit(X_pategan, y_pategan)

# Uji model di data asli
y_pred_logreg = model_logreg.predict(X_real)

# %%
# Tampilkan hasil evaluasi
print("📊 Performance (Logistic Regression — Train on pategan → Test on REAL):")
print(classification_report(y_real, y_pred_logreg))
# Out:
# 📊 Performance (Logistic Regression — Train on pategan → Test on REAL):
#               precision    recall  f1-score   support
#
#            0       0.70      0.14      0.23        50
#            1       0.52      0.94      0.67        50
#
#     accuracy                           0.54       100
#    macro avg       0.61      0.54      0.45       100
# weighted avg       0.61      0.54      0.45       100

# %% [markdown]
# **HYPERPARAMETER TUNING**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Bersihkan jika ada kolom tambahan
X_pategan = X_pategan.drop(columns=['Unnamed: 0'], errors='ignore')
X_real = X_real.drop(columns=['Unnamed: 0'], errors='ignore')

# Definisikan model dasar
logreg = LogisticRegression()

# Parameter grid untuk tuning
param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear'],  # liblinear support l1 & l2
    'max_iter': [100, 300, 1000]
}

# Inisialisasi GridSearch
grid = GridSearchCV(
    estimator=logreg,
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    verbose=1,
    n_jobs=-1
)
# 🚀 Tuning dengan data sintetik
grid.fit(X_pategan, y_pategan)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10], 'max_iter': [100, 300, 1000],
#                          'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='accuracy', verbose=1)

# %%
# Prediksi di data asli
best_logreg = grid.best_estimator_
y_pred_tuned = best_logreg.predict(X_real)

# %%
# Hasil akhir
print("📌 Best Params:", grid.best_params_)
print("\n📊 Performance (Logistic Regression TUNED — Train on pategan → Test on REAL):")
print(classification_report(y_real, y_pred_tuned))
# Out:
# 📌 Best Params: {'C': 0.01, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#
# 📊 Performance (Logistic Regression TUNED — Train on pategan → Test on REAL):
#               precision    recall  f1-score   support
#
#            0       0.54      0.14      0.22        50
#            1       0.51      0.88      0.64        50
#
#     accuracy                           0.51       100
#    macro avg       0.52      0.51      0.43       100
# weighted avg       0.52      0.51      0.43       100

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Fungsi bantu
def get_X_y(df):
    X = df.drop(columns=["GRUP"])
    y = df["GRUP"]
    return X, y

# Ambil data training & testing
X_real, y_real = get_X_y(df_real)
X_pategan, y_pategan = get_X_y(df_pategan)

# %%
# Bersihkan kolom 'Unnamed: 0' jika ada
X_pategan = X_pategan.drop(columns=['Unnamed: 0'], errors='ignore')
X_real = X_real.drop(columns=['Unnamed: 0'], errors='ignore')

# Inisialisasi model SVM
model_svm = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)

# %%
# 🚀 Train model di data sintetik (Bayesian)
model_svm.fit(X_pategan, y_pategan)

# 🧪 Test model di data asli
y_pred_svm = model_svm.predict(X_real)

# 📊 Tampilkan hasil evaluasi
print("📊 Performance (SVM — Train on pategan → Test on REAL):")
print(classification_report(y_real, y_pred_svm))
# Out:
# 📊 Performance (SVM — Train on pategan → Test on REAL):
#               precision    recall  f1-score   support
#
#            0       0.68      0.26      0.38        50
#            1       0.54      0.88      0.67        50
#
#     accuracy                           0.57       100
#    macro avg       0.61      0.57      0.52       100
# weighted avg       0.61      0.57      0.52       100

# %% [markdown]
# **HYPERPARAMETER TUNING**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Bersihkan kolom jika ada 'Unnamed: 0'
X_pategan = X_pategan.drop(columns=['Unnamed: 0'], errors='ignore')
X_real = X_real.drop(columns=['Unnamed: 0'], errors='ignore')

# Definisikan model dasar
svm = SVC()

# Parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.01, 0.1, 1],
    'kernel': ['rbf', 'linear']
}

# Setup GridSearch
grid = GridSearchCV(
    estimator=svm,
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    verbose=1,
    n_jobs=-1
)

# %%
# 🚀 Training model di data sintetik (Bayesian)
grid.fit(X_pategan, y_pategan)

# 🧪 Uji di data asli
best_svm = grid.best_estimator_
y_pred_tuned_svm = best_svm.predict(X_real)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits

# %%
# 📝 Hasil
print("📌 Best Hyperparameters (SVM):", grid.best_params_)
print("\n📊 Performance (TUNED SVM — Train on pategan → Test on REAL):")
print(classification_report(y_real, y_pred_tuned_svm))
# Out:
# 📌 Best Hyperparameters (SVM): {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
#
# 📊 Performance (TUNED SVM — Train on pategan → Test on REAL):
#               precision    recall  f1-score   support
#
#            0       0.69      0.22      0.33        50
#            1       0.54      0.90      0.67        50
#
#     accuracy                           0.56       100
#    macro avg       0.61      0.56      0.50       100
# weighted avg       0.61      0.56      0.50       100
